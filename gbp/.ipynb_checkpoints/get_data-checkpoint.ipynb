# %%
import pandas as pd
import numpy as np
import MySQLdb
import re
from datetime import datetime
from matplotlib import pyplot as plt
conn = MySQLdb.connect(host='54.65.19.253', port=3306, user='news', passwd='newsnews', db='news')

# %%
news_title = pd.read_csv('news_title.csv')
news_title.head()
# Out:
#                                                 name  class         date  \
# 0  cia exposed by frontline role along afghanista...  world  2010/jan/01
# 1  iraq threatens action after blackwater case co...  world  2010/jan/01
# 2  racial or religious groups could be picked out...  world  2010/jan/01
# 3           us general  british hostage held in iran  world  2010/jan/01
# 4  pakistan suicide bomber kills dozens at volley...  world  2010/jan/01
#
#     timestamp
# 0  1262275200
# 1  1262275200
# 2  1262275200
# 3  1262275200
# 4  1262275200

# %%
def getdata(news_class):
    conn = MySQLdb.connect(host='54.65.19.253', port=3306, user='news', passwd='newsnews', db='news')
    news = pd.read_csv('news_title.csv')
    news = news.loc[news['class'].isin(news_class)]
    news = news.drop(['date', 'class'], axis=1)
    news = news.groupby('timestamp', as_index=False).agg(lambda name: ' '.join(name))
    gbp = pd.read_sql('SELECT gbp.timestamp, gbp \
                FROM gbp \
                WHERE gbp.timestamp >= 1262275200;', conn)
    news = pd.merge(news, gbp, on='timestamp', how='inner')
    return news

# %%
news_class = ['word','business']#['lifestyle','travel']
data = getdata(news_class)

# %%
data
# Out:
#        timestamp                                               name       gbp
# 0     1262275200  green technology to be used by top firms to ov...  1.616810
# 1     1262448000  dispute looms as russia suspends belarus energ...  1.616800
# 2     1262534400  how solid is northern rock without government ...  1.610591
# 3     1262620800  fears of higher interest rates as leading bond...  1.600088
# 4     1262707200  bad weather casts cloud over industry icelandi...  1.601267
# 5     1262793600  energy infrastructure needs renewing bus inqui...  1.591234
# 6     1262880000  bonus time as banks pay out  bn gm seeks to cl...  1.599166
# 7     1262966400         investors get tough over bosses  tax deals  1.602100
# 8     1263052800  mitchells butlers in peace talks with rebel in...  1.602100
# 9     1263139200  petrol engines will rule for at least another ...  1.614429
# 10    1263225600  general motors  if saab bidders are not sound ...  1.618031
# 11    1263312000  us taxpayers gave banks kiss of life wall stre...  1.628565
# 12    1263398400  angry obama vows to tax cash rich wall street ...  1.632267
# 13    1263484800  mitchells butlers activists win backing from t...  1.623972
# 14    1263571200  sir fred goodwin given job by scottish parliam...  1.626550
# 15    1263657600  gdf suez launches international power bid cadb...  1.626200
# 16    1263744000  kraft set for higher cadbury bid as deadline l...  1.632554
# 17    1263830400  business donors to haiti  which companies are ...  1.636785
# 18    1263916800  surprise drop in unemployment presents brown w...  1.628541
# 19    1264003200  wall street bank shares slump as impact of oba...  1.620529
